# %% [markdown]
# # DATA EXTRACTION

# %%
import zipfile
import os

# Define the ZIP file name and extraction path
zip_path = 'datasets.zip'
extract_path = './'

# Create the destination folder if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the ZIP file contents
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"✅ Dataset successfully extracted")
# Out:
# ✅ Dataset successfully extracted

# %% [markdown]
# # BASIC INFO AND STATISTICS

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('datasets/test_0_rows_500_columns_20_comp_0.5_input_.csv')

# Display shape
print("Dataset shape:", df.shape)

# Show basic info
print("\nData types and non-null counts:")
df.info()

# Show percentage of missing values per column
missing_percentage = df.isnull().mean() * 100
print("\nPercentage of missing values per column:")
print(missing_percentage.sort_values(ascending=False))

# Show basic statistics
print("\nDescriptive statistics:")
print(df.describe())

# Display first few rows
df.head()
# Out:
# Dataset shape: (500, 20)
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_0   238 non-null    float64
#  1   col_1   251 non-null    float64
#  2   col_2   245 non-null    float64
#  3   col_3   250 non-null    float64
#  4   col_4   265 non-null    float64
#  5   col_5   256 non-null    float64
#  6   col_6   259 non-null    float64
#  7   col_7   249 non-null    float64
#  8   col_8   262 non-null    float64
#  9   col_9   262 non-null    float64
#  10  col_10  256 non-null    float64
#  11  col_11  244 non-null    float64
#  12  col_12  251 non-null    float64
#  13  col_13  249 non-null    float64
#  14  col_14  247 non-null    float64
#  15  col_15  243 non-null    float64
#  16  col_16  249 non-null    float64
#  17  col_17  249 non-null    float64
#  18  col_18  252 non-null    float64
# ...

# %%
# Contar cuántas filas están completamente completas (sin ningún valor nulo)
complete_rows = df.dropna().shape[0]
print(f"\nNúmero de filas completas (sin valores nulos): {complete_rows}")
# Out:
# Número de filas completas (sin valores nulos): 204

# %%
percent_complete_rows = (complete_rows / df.shape[0]) * 100
print(f"Porcentaje de filas completas: {percent_complete_rows:.2f}%")
# Out:
# Porcentaje de filas completas: 40.80%
